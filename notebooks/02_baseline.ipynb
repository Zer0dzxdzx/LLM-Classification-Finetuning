# %% [markdown]
# # 02 Baseline
#
# Train TF-IDF + Logistic Regression, inspect validation metrics, and generate a submission file.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path('/kaggle/working')
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = Path('..').resolve()
sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %%
from src.config import load_config
from src.train import run_training

config_path = PROJECT_ROOT / 'configs' / 'baseline.yaml'
if not Path('/kaggle/input/llm-classification-finetuning/train.csv').exists():
    config_path = PROJECT_ROOT / 'configs' / 'local_sample.yaml'

config = load_config(config_path)
metrics = run_training(config)
metrics

# %%
from src.predict import run_prediction

output_path = PROJECT_ROOT / 'submissions' / 'submission.csv'
if config_path.name == 'local_sample.yaml':
    output_path = PROJECT_ROOT / 'outputs' / 'submission_sample.csv'

result = run_prediction(config, output_path)
result

# %%
import pandas as pd
submission = pd.read_csv(output_path)
submission.head()
